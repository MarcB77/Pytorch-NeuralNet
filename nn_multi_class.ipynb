# %% [markdown]
# Multi classification, position of footbalplayers based on personalized data.

# %%
import torch
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch import nn, optim
import torch.nn.functional as F
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.2)
HAPPY_COLORS_PALETTE =\
["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]
sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))
rcParams['figure.figsize'] = 12, 8
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %%
df = pd.read_csv('data/football_players_multi.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
cols = ['Position','Age','Overall','Potential','Special','Weak Foot','Skill Moves','Jersey Number','Crossing','Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve','FKAccuracy','LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower','Jumping','Stamina','Strength','LongShots','Aggression','Interceptions','Positioning','Vision','Penalties','Composure','Marking']
df = df[cols]

# %%
forward_player = ["ST", "LW", "RW", "LF", "RF", "RS","LS", "CF"]
midfielder_player = ["CM","RCM","LCM", "CDM","RDM","LDM", "CAM", "LAM", "RAM", "RM", "LM"]
defender_player = ["CB", "RCB", "LCB", "LWB", "RWB", "LB", "RB"]

df.loc[df["Position"] == "GK", "Position"] = 0
df.loc[df["Position"].isin(defender_player), "Position"] = 1
df.loc[df["Position"].isin(midfielder_player), "Position"] = 2
df.loc[df["Position"].isin(forward_player), "Position"] = 3

# %%
print(df.isna().sum())
print(len(df))
df = df.dropna(how='any')
print(len(df))
# Out:
# Position           60
# Age                 0
# Overall             0
# Potential           0
# Special             0
# Weak Foot          48
# Skill Moves        48
# Jersey Number      60
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# dtype: int64
# 18207
# 18147

# %%
X = df.drop(['Position'],axis = 1) 
df['Position'] = df['Position'].astype(float)
y = df[['Position']]
print(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED)
# Out:
#        Position
# 0           3.0
# 1           3.0
# 2           3.0
# 3           0.0
# 4           2.0
# ...         ...
# 18202       2.0
# 18203       3.0
# 18204       3.0
# 18205       3.0
# 18206       2.0
#
# [18147 rows x 1 columns]

# %%
BATCH_SIZE=32
EPOCH = 150

X_train = torch.from_numpy(X_train.to_numpy()).float()
y_train = torch.squeeze(torch.from_numpy(y_train.to_numpy()).float())
X_test = torch.from_numpy(X_test.to_numpy()).float()
y_test = torch.squeeze(torch.from_numpy(y_test.to_numpy()).float())
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

train = torch.utils.data.TensorDataset(X_train,y_train)
validate = torch.utils.data.TensorDataset(X_test,y_test)

train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = True)
val_loader = torch.utils.data.DataLoader(validate, batch_size = BATCH_SIZE, shuffle = False)
# Out:
# torch.Size([14517, 34]) torch.Size([14517])
# torch.Size([3630, 34]) torch.Size([3630])

# %%
import time
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
class Net(nn.Module):
  def __init__(self, n_features):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(n_features, 10)
    self.fc2 = nn.Linear(10, 5)
    self.fc3 = nn.Linear(5, 4)
  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x
net = Net(X_train.shape[1])

# %%
from tqdm.notebook import tqdm

#criterion = nn.BCELoss()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)
net = net.to(device)
print(net)
criterion = criterion.to(device)

predicted_list = []
train_acc_per_epoch = []
val_acc_per_epoch = []

for epoch in tqdm(range(EPOCH)):
    start_time = time.time()
    correct = 0
    total = 0
    for i, data in enumerate(train_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = (inputs).type(torch.FloatTensor), (labels).type(torch.LongTensor)
        y_pred = net(inputs)
        #print(labels, y_pred)
        train_loss = criterion(y_pred, labels)

        #predicted = torch.round(y_pred).int()
        #predicted_list.append(predicted.tolist())
        predicted = torch.max(y_pred,1)
        total += labels.size(0)
        correct += (predicted[1] == labels).sum().item()
        #print(predicted[1], labels)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

    train_acc = correct / total
    train_acc_per_epoch.append(train_acc)
    correct = 0
    total = 0
    
    #VALIDATION SET
    predicted_list=[] # reset every epoch, and save the last one
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        inputs, labels = (inputs).type(torch.FloatTensor), (labels).type(torch.LongTensor)

        # calculate outputs by running images through the network 
        y_pred = net(inputs)
        
        predicted = torch.max(y_pred,1)
        #predicted_list.append(predicted.tolist()) 
        #predicted = torch.squeeze(predicted)
        total += labels.size(0)
        correct += (predicted[1] == labels).sum().item()
        #print(predicted[1], labels)
        predicted_list.append(predicted[1].tolist()) 

    vall_acc = correct / total
    val_acc_per_epoch.append(vall_acc)
    correct = 0
    total = 0

    end_time = time.time()
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    #print(f'train_loss : {epoch_train_loss}')
    print(f'train_accuracy : {train_acc*100} val_accuracy : {vall_acc*100}')
    print(25*'==')
# Out:
# Net(
#   (fc1): Linear(in_features=34, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=5, bias=True)
#   (fc3): Linear(in_features=5, out_features=4, bias=True)
# )
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# Epoch: 01 | Epoch Time: 0m 1s
# train_accuracy : 44.92663773506923 val_accuracy : 60.0
# ==================================================
# Epoch: 02 | Epoch Time: 0m 0s
# train_accuracy : 63.11221326720396 val_accuracy : 66.85950413223141
# ==================================================
# Epoch: 03 | Epoch Time: 0m 1s
# train_accuracy : 67.68616105255907 val_accuracy : 70.3030303030303
# ==================================================
# Epoch: 04 | Epoch Time: 0m 1s
# train_accuracy : 70.9512984776469 val_accuracy : 73.4435261707989
# ==================================================
# Epoch: 05 | Epoch Time: 0m 0s
# train_accuracy : 74.61596748639526 val_accuracy : 75.75757575757575
# ==================================================
# Epoch: 06 | Epoch Time: 0m 1s
# train_accuracy : 79.56878142866984 val_accuracy : 82.58953168044077
# ==================================================
# Epoch: 07 | Epoch Time: 0m 1s
# train_accuracy : 81.71109733415996 val_accuracy : 83.38842975206612
# ==================================================
# Epoch: 08 | Epoch Time: 0m 0s
# train_accuracy : 82.52393745264173 val_accuracy : 83.60881542699724
# ==================================================
# Epoch: 09 | Epoch Time: 0m 0s
# train_accuracy : 82.58593373286492 val_accuracy : 82.47933884297521
# ==================================================
# Epoch: 10 | Epoch Time: 0m 1s
# train_accuracy : 82.99235379210582 val_accuracy : 84.24242424242424
# ==================================================
# Epoch: 11 | Epoch Time: 0m 0s
# train_accuracy : 83.10256940139146 val_accuracy : 85.50964187327824
# ==================================================
# Epoch: 12 | Epoch Time: 0m 0s
# train_accuracy : 83.76386305710545 val_accuracy : 85.45454545454545
# ==================================================
# Epoch: 13 | Epoch Time: 0m 0s
# train_accuracy : 84.10139836054282 val_accuracy : 85.78512396694215
# ==================================================
# Epoch: 14 | Epoch Time: 0m 0s
# train_accuracy : 84.28049872563201 val_accuracy : 85.92286501377411
# ==================================================
# Epoch: 15 | Epoch Time: 0m 0s
# train_accuracy : 84.94868085692636 val_accuracy : 86.47382920110192
# ==================================================
# Epoch: 16 | Epoch Time: 0m 0s
# train_accuracy : 84.6731418337122 val_accuracy : 86.44628099173553
# ==================================================
# Epoch: 17 | Epoch Time: 0m 0s
# train_accuracy : 85.24488530688159 val_accuracy : 86.61157024793388
# ==================================================
# Epoch: 18 | Epoch Time: 0m 0s
# train_accuracy : 85.39643176964937 val_accuracy : 86.36363636363636
# ==================================================
# Epoch: 19 | Epoch Time: 0m 0s
# train_accuracy : 85.3619893917476 val_accuracy : 85.50964187327824
# ==================================================
# Epoch: 20 | Epoch Time: 0m 0s
# train_accuracy : 85.45842804987257 val_accuracy : 87.05234159779614
# ==================================================
# Epoch: 21 | Epoch Time: 0m 0s
# train_accuracy : 85.49975890335469 val_accuracy : 86.99724517906337
# ==================================================
# Epoch: 22 | Epoch Time: 0m 0s
# train_accuracy : 85.78907487772955 val_accuracy : 85.81267217630854
# ==================================================
# Epoch: 23 | Epoch Time: 0m 0s
# train_accuracy : 85.94750981607771 val_accuracy : 87.71349862258954
# ==================================================
# Epoch: 24 | Epoch Time: 0m 0s
# train_accuracy : 86.0095060963009 val_accuracy : 87.57575757575758
# ==================================================
# Epoch: 25 | Epoch Time: 0m 0s
# train_accuracy : 86.09216780326514 val_accuracy : 86.94214876033057
# ==================================================
# Epoch: 26 | Epoch Time: 0m 0s
# train_accuracy : 86.07839085210442 val_accuracy : 86.91460055096418
# ==================================================
# Epoch: 27 | Epoch Time: 0m 0s
# train_accuracy : 86.34704139973823 val_accuracy : 87.35537190082646
# ==================================================
# Epoch: 28 | Epoch Time: 0m 0s
# train_accuracy : 86.30571054625611 val_accuracy : 87.76859504132231
# ==================================================
# Epoch: 29 | Epoch Time: 0m 0s
# train_accuracy : 86.15416408348833 val_accuracy : 87.98898071625344
# ==================================================
# Epoch: 30 | Epoch Time: 0m 0s
# train_accuracy : 86.29882207067577 val_accuracy : 87.85123966942149
# ==================================================
# Epoch: 31 | Epoch Time: 0m 0s
# train_accuracy : 86.4434800578632 val_accuracy : 85.59228650137742
# ==================================================
# Epoch: 32 | Epoch Time: 0m 0s
# train_accuracy : 86.22304883929186 val_accuracy : 86.85950413223141
# ==================================================
# Epoch: 33 | Epoch Time: 0m 0s
# train_accuracy : 86.51236481366674 val_accuracy : 87.63085399449035
# ==================================================
# Epoch: 34 | Epoch Time: 0m 0s
# train_accuracy : 86.51236481366674 val_accuracy : 87.87878787878788
# ==================================================
# Epoch: 35 | Epoch Time: 0m 0s
# train_accuracy : 86.64324584969346 val_accuracy : 86.2534435261708
# ==================================================
# Epoch: 36 | Epoch Time: 0m 0s
# train_accuracy : 86.47103396018461 val_accuracy : 88.34710743801652
# ==================================================
# Epoch: 37 | Epoch Time: 0m 1s
# train_accuracy : 86.52614176482744 val_accuracy : 87.8236914600551
# ==================================================
# Epoch: 38 | Epoch Time: 0m 0s
# train_accuracy : 86.57436109388992 val_accuracy : 88.23691460055096
# ==================================================
# Epoch: 39 | Epoch Time: 0m 0s
# train_accuracy : 86.62946889853276 val_accuracy : 87.19008264462809
# ==================================================
# Epoch: 40 | Epoch Time: 0m 0s
# train_accuracy : 86.51925328924709 val_accuracy : 87.10743801652893
# ==================================================
# Epoch: 41 | Epoch Time: 0m 0s
# train_accuracy : 86.80168078804161 val_accuracy : 88.51239669421489
# ==================================================
# Epoch: 42 | Epoch Time: 0m 0s
# train_accuracy : 86.83612316594338 val_accuracy : 87.65840220385674
# ==================================================
# Epoch: 43 | Epoch Time: 0m 0s
# train_accuracy : 86.69835365433629 val_accuracy : 88.4573002754821
# ==================================================
# Epoch: 44 | Epoch Time: 0m 0s
# train_accuracy : 86.98766962871116 val_accuracy : 88.07162534435263
# ==================================================
# Epoch: 45 | Epoch Time: 0m 0s
# train_accuracy : 86.40903767996141 val_accuracy : 88.18181818181819
# ==================================================
# Epoch: 46 | Epoch Time: 0m 0s
# train_accuracy : 86.80856926362196 val_accuracy : 88.51239669421489
# ==================================================
# Epoch: 47 | Epoch Time: 0m 0s
# train_accuracy : 86.92567334848798 val_accuracy : 86.96969696969697
# ==================================================
# Epoch: 48 | Epoch Time: 0m 0s
# train_accuracy : 87.17365846938073 val_accuracy : 87.98898071625344
# ==================================================
# Epoch: 49 | Epoch Time: 0m 0s
# train_accuracy : 87.21498932286285 val_accuracy : 87.54820936639118
# ==================================================
# Epoch: 50 | Epoch Time: 0m 0s
# train_accuracy : 87.07721981125577 val_accuracy : 88.34710743801652
# ==================================================
# Epoch: 51 | Epoch Time: 0m 0s
# train_accuracy : 86.93945029964868 val_accuracy : 88.40220385674931
# ==================================================
# Epoch: 52 | Epoch Time: 0m 0s
# train_accuracy : 87.02900048219328 val_accuracy : 87.90633608815426
# ==================================================
# Epoch: 53 | Epoch Time: 0m 0s
# train_accuracy : 87.1185506647379 val_accuracy : 88.29201101928375
# ==================================================
# Epoch: 54 | Epoch Time: 0m 0s
# train_accuracy : 87.36653578563065 val_accuracy : 88.62258953168045
# ==================================================
# Epoch: 55 | Epoch Time: 0m 0s
# train_accuracy : 87.2218777984432 val_accuracy : 88.34710743801652
# ==================================================
# Epoch: 56 | Epoch Time: 0m 0s
# train_accuracy : 87.1185506647379 val_accuracy : 88.20936639118457
# ==================================================
# Epoch: 57 | Epoch Time: 0m 0s
# train_accuracy : 86.97389267755045 val_accuracy : 88.1267217630854
# ==================================================
# Epoch: 58 | Epoch Time: 0m 0s
# train_accuracy : 87.19432389612179 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 59 | Epoch Time: 0m 0s
# train_accuracy : 87.0703313356754 val_accuracy : 88.34710743801652
# ==================================================
# Epoch: 60 | Epoch Time: 0m 0s
# train_accuracy : 87.042777433354 val_accuracy : 88.70523415977961
# ==================================================
# Epoch: 61 | Epoch Time: 0m 0s
# train_accuracy : 87.07721981125577 val_accuracy : 87.87878787878788
# ==================================================
# Epoch: 62 | Epoch Time: 0m 1s
# train_accuracy : 87.49741682165737 val_accuracy : 88.53994490358127
# ==================================================
# Epoch: 63 | Epoch Time: 0m 0s
# train_accuracy : 87.32520493214851 val_accuracy : 87.52066115702479
# ==================================================
# Epoch: 64 | Epoch Time: 0m 0s
# train_accuracy : 87.4767513949163 val_accuracy : 88.65013774104683
# ==================================================
# Epoch: 65 | Epoch Time: 0m 0s
# train_accuracy : 87.33209340772888 val_accuracy : 87.41046831955923
# ==================================================
# Epoch: 66 | Epoch Time: 0m 0s
# train_accuracy : 87.2081008472825 val_accuracy : 87.98898071625344
# ==================================================
# Epoch: 67 | Epoch Time: 0m 0s
# train_accuracy : 87.31831645656816 val_accuracy : 88.48484848484848
# ==================================================
# Epoch: 68 | Epoch Time: 0m 0s
# train_accuracy : 87.4767513949163 val_accuracy : 88.51239669421489
# ==================================================
# Epoch: 69 | Epoch Time: 0m 0s
# train_accuracy : 87.36653578563065 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 70 | Epoch Time: 0m 0s
# train_accuracy : 87.31831645656816 val_accuracy : 86.94214876033057
# ==================================================
# Epoch: 71 | Epoch Time: 0m 0s
# train_accuracy : 87.11166218915753 val_accuracy : 88.59504132231405
# ==================================================
# Epoch: 72 | Epoch Time: 0m 0s
# train_accuracy : 87.6558517600055 val_accuracy : 88.89807162534436
# ==================================================
# Epoch: 73 | Epoch Time: 0m 0s
# train_accuracy : 87.34587035888957 val_accuracy : 88.67768595041322
# ==================================================
# Epoch: 74 | Epoch Time: 0m 0s
# train_accuracy : 87.4767513949163 val_accuracy : 88.62258953168045
# ==================================================
# Epoch: 75 | Epoch Time: 0m 0s
# train_accuracy : 87.29076255424675 val_accuracy : 88.87052341597797
# ==================================================
# Epoch: 76 | Epoch Time: 0m 0s
# train_accuracy : 87.51119377281807 val_accuracy : 88.07162534435263
# ==================================================
# Epoch: 77 | Epoch Time: 0m 0s
# train_accuracy : 87.57319005304126 val_accuracy : 86.99724517906337
# ==================================================
# Epoch: 78 | Epoch Time: 0m 0s
# train_accuracy : 87.6558517600055 val_accuracy : 88.73278236914601
# ==================================================
# Epoch: 79 | Epoch Time: 0m 0s
# train_accuracy : 87.58007852862161 val_accuracy : 88.29201101928375
# ==================================================
# Epoch: 80 | Epoch Time: 0m 1s
# train_accuracy : 87.72473651580906 val_accuracy : 88.34710743801652
# ==================================================
# Epoch: 81 | Epoch Time: 0m 1s
# train_accuracy : 87.26320865192532 val_accuracy : 88.53994490358127
# ==================================================
# Epoch: 82 | Epoch Time: 0m 1s
# train_accuracy : 87.45608596817524 val_accuracy : 87.19008264462809
# ==================================================
# Epoch: 83 | Epoch Time: 0m 1s
# train_accuracy : 87.62829785768409 val_accuracy : 87.76859504132231
# ==================================================
# Epoch: 84 | Epoch Time: 0m 1s
# train_accuracy : 87.72473651580906 val_accuracy : 88.40220385674931
# ==================================================
# Epoch: 85 | Epoch Time: 0m 0s
# train_accuracy : 87.35964731005028 val_accuracy : 88.29201101928375
# ==================================================
# Epoch: 86 | Epoch Time: 0m 1s
# train_accuracy : 87.51119377281807 val_accuracy : 86.99724517906337
# ==================================================
# Epoch: 87 | Epoch Time: 0m 0s
# train_accuracy : 87.46986291933595 val_accuracy : 88.73278236914601
# ==================================================
# Epoch: 88 | Epoch Time: 0m 0s
# train_accuracy : 87.59385547978232 val_accuracy : 88.26446280991735
# ==================================================
# Epoch: 89 | Epoch Time: 0m 1s
# train_accuracy : 87.704071089068 val_accuracy : 88.92561983471074
# ==================================================
# Epoch: 90 | Epoch Time: 0m 2s
# train_accuracy : 87.67651718674657 val_accuracy : 88.59504132231405
# ==================================================
# Epoch: 91 | Epoch Time: 0m 1s
# train_accuracy : 87.45608596817524 val_accuracy : 87.74104683195593
# ==================================================
# Epoch: 92 | Epoch Time: 0m 0s
# train_accuracy : 87.50430529723772 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 93 | Epoch Time: 0m 0s
# train_accuracy : 87.62829785768409 val_accuracy : 88.70523415977961
# ==================================================
# Epoch: 94 | Epoch Time: 0m 1s
# train_accuracy : 87.76606736929118 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 95 | Epoch Time: 0m 0s
# train_accuracy : 87.88317145415719 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 96 | Epoch Time: 0m 0s
# train_accuracy : 87.82806364951436 val_accuracy : 88.62258953168045
# ==================================================
# Epoch: 97 | Epoch Time: 0m 0s
# train_accuracy : 87.74540194255012 val_accuracy : 89.11845730027548
# ==================================================
# Epoch: 98 | Epoch Time: 0m 1s
# train_accuracy : 87.52497072397878 val_accuracy : 88.51239669421489
# ==================================================
# Epoch: 99 | Epoch Time: 0m 1s
# train_accuracy : 87.58696700420197 val_accuracy : 87.46556473829202
# ==================================================
# Epoch: 100 | Epoch Time: 0m 0s
# train_accuracy : 87.66274023558587 val_accuracy : 89.17355371900827
# ==================================================
# Epoch: 101 | Epoch Time: 0m 1s
# train_accuracy : 87.66274023558587 val_accuracy : 89.22865013774106
# ==================================================
# Epoch: 102 | Epoch Time: 0m 0s
# train_accuracy : 87.75229041813046 val_accuracy : 88.53994490358127
# ==================================================
# Epoch: 103 | Epoch Time: 0m 0s
# train_accuracy : 87.44230901701454 val_accuracy : 88.92561983471074
# ==================================================
# Epoch: 104 | Epoch Time: 0m 0s
# train_accuracy : 87.7178480402287 val_accuracy : 88.89807162534436
# ==================================================
# Epoch: 105 | Epoch Time: 0m 1s
# train_accuracy : 87.77295584487152 val_accuracy : 88.20936639118457
# ==================================================
# Epoch: 106 | Epoch Time: 0m 1s
# train_accuracy : 87.58696700420197 val_accuracy : 88.65013774104683
# ==================================================
# Epoch: 107 | Epoch Time: 0m 1s
# train_accuracy : 87.72473651580906 val_accuracy : 88.59504132231405
# ==================================================
# Epoch: 108 | Epoch Time: 0m 0s
# train_accuracy : 87.75229041813046 val_accuracy : 88.87052341597797
# ==================================================
# Epoch: 109 | Epoch Time: 0m 0s
# train_accuracy : 87.9864985878625 val_accuracy : 88.67768595041322
# ==================================================
# Epoch: 110 | Epoch Time: 0m 0s
# train_accuracy : 87.82806364951436 val_accuracy : 87.8236914600551
# ==================================================
# Epoch: 111 | Epoch Time: 0m 0s
# train_accuracy : 87.86250602741613 val_accuracy : 88.81542699724518
# ==================================================
# Epoch: 112 | Epoch Time: 0m 0s
# train_accuracy : 87.74540194255012 val_accuracy : 89.0358126721763
# ==================================================
# Epoch: 113 | Epoch Time: 0m 0s
# train_accuracy : 87.87628297857684 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 114 | Epoch Time: 0m 0s
# train_accuracy : 88.0002755390232 val_accuracy : 88.81542699724518
# ==================================================
# Epoch: 115 | Epoch Time: 0m 0s
# train_accuracy : 87.63518633326444 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 116 | Epoch Time: 0m 0s
# train_accuracy : 87.71095956464833 val_accuracy : 88.98071625344353
# ==================================================
# Epoch: 117 | Epoch Time: 0m 0s
# train_accuracy : 87.83495212509472 val_accuracy : 88.87052341597797
# ==================================================
# Epoch: 118 | Epoch Time: 0m 0s
# train_accuracy : 87.72473651580906 val_accuracy : 88.98071625344353
# ==================================================
# Epoch: 119 | Epoch Time: 0m 0s
# train_accuracy : 87.88317145415719 val_accuracy : 89.06336088154269
# ==================================================
# Epoch: 120 | Epoch Time: 0m 0s
# train_accuracy : 87.76606736929118 val_accuracy : 89.0358126721763
# ==================================================
# Epoch: 121 | Epoch Time: 0m 0s
# train_accuracy : 87.77295584487152 val_accuracy : 89.14600550964187
# ==================================================
# Epoch: 122 | Epoch Time: 0m 0s
# train_accuracy : 87.7936212716126 val_accuracy : 88.62258953168045
# ==================================================
# Epoch: 123 | Epoch Time: 0m 0s
# train_accuracy : 87.8969484053179 val_accuracy : 88.20936639118457
# ==================================================
# Epoch: 124 | Epoch Time: 0m 0s
# train_accuracy : 88.15871047737136 val_accuracy : 88.56749311294766
# ==================================================
# Epoch: 125 | Epoch Time: 0m 1s
# train_accuracy : 87.77984432045189 val_accuracy : 88.48484848484848
# ==================================================
# Epoch: 126 | Epoch Time: 0m 0s
# train_accuracy : 87.8969484053179 val_accuracy : 88.1267217630854
# ==================================================
# Epoch: 127 | Epoch Time: 0m 0s
# train_accuracy : 87.77984432045189 val_accuracy : 87.93388429752066
# ==================================================
# Epoch: 128 | Epoch Time: 0m 0s
# train_accuracy : 87.97961011228215 val_accuracy : 88.7878787878788
# ==================================================
# Epoch: 129 | Epoch Time: 0m 1s
# train_accuracy : 87.81428669835365 val_accuracy : 89.0358126721763
# ==================================================
# Epoch: 130 | Epoch Time: 0m 0s
# train_accuracy : 87.87628297857684 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 131 | Epoch Time: 0m 1s
# train_accuracy : 87.97961011228215 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 132 | Epoch Time: 0m 1s
# train_accuracy : 87.75917889371082 val_accuracy : 88.1267217630854
# ==================================================
# Epoch: 133 | Epoch Time: 0m 0s
# train_accuracy : 87.8073982227733 val_accuracy : 88.37465564738292
# ==================================================
# Epoch: 134 | Epoch Time: 0m 2s
# train_accuracy : 87.89005992973755 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 135 | Epoch Time: 0m 2s
# train_accuracy : 88.10360267272853 val_accuracy : 88.84297520661157
# ==================================================
# Epoch: 136 | Epoch Time: 0m 2s
# train_accuracy : 87.95894468554108 val_accuracy : 89.06336088154269
# ==================================================
# Epoch: 137 | Epoch Time: 0m 1s
# train_accuracy : 88.06227181924639 val_accuracy : 87.85123966942149
# ==================================================
# Epoch: 138 | Epoch Time: 0m 2s
# train_accuracy : 88.0002755390232 val_accuracy : 89.0909090909091
# ==================================================
# Epoch: 139 | Epoch Time: 0m 1s
# train_accuracy : 88.17937590411242 val_accuracy : 88.7603305785124
# ==================================================
# Epoch: 140 | Epoch Time: 0m 1s
# train_accuracy : 87.85561755183578 val_accuracy : 88.87052341597797
# ==================================================
# Epoch: 141 | Epoch Time: 0m 0s
# train_accuracy : 87.87628297857684 val_accuracy : 89.22865013774106
# ==================================================
# Epoch: 142 | Epoch Time: 0m 1s
# train_accuracy : 88.0002755390232 val_accuracy : 89.14600550964187
# ==================================================
# Epoch: 143 | Epoch Time: 0m 1s
# train_accuracy : 87.97961011228215 val_accuracy : 88.53994490358127
# ==================================================
# Epoch: 144 | Epoch Time: 0m 2s
# train_accuracy : 87.84872907625542 val_accuracy : 89.06336088154269
# ==================================================
# Epoch: 145 | Epoch Time: 0m 1s
# train_accuracy : 87.95205620996074 val_accuracy : 88.37465564738292
# ==================================================
# Epoch: 146 | Epoch Time: 0m 1s
# train_accuracy : 88.03471791692499 val_accuracy : 89.366391184573
# ==================================================
# Epoch: 147 | Epoch Time: 0m 1s
# train_accuracy : 88.33781084246056 val_accuracy : 88.37465564738292
# ==================================================
# Epoch: 148 | Epoch Time: 0m 1s
# train_accuracy : 87.86250602741613 val_accuracy : 87.90633608815426
# ==================================================
# Epoch: 149 | Epoch Time: 0m 1s
# train_accuracy : 87.85561755183578 val_accuracy : 88.53994490358127
# ==================================================
# Epoch: 150 | Epoch Time: 0m 1s
# train_accuracy : 87.89005992973755 val_accuracy : 89.06336088154269
# ==================================================

# %% [markdown]
# PLOT TRAINING STATS

# %%
import matplotlib.pyplot as plt
#plt.style.use("seaborn-dark")
for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '1.0'#'#212946'  # bluish dark grey
for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.3'  # very light grey
epochs_range = np.arange(1,EPOCH+1)
plt.plot(epochs_range, train_acc_per_epoch, 'g', label='Train Accuracy NN')
plt.plot(epochs_range, val_acc_per_epoch, 'b', label='Val Accuracy MLP')
#plt.grid(color='#2A3459')  # bluish dark grey, but slightly lighter than background
plt.title('Accuracies of MLP')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# CHECK RESULTS IN CSV, A SAMPLE

# %%
flat_predicted = [item for sublist in predicted_list for item in sublist]
predictions_df = pd.DataFrame()
predictions_df['predicted'] = flat_predicted
predictions_df['true value'] = y_test
predictions_df.to_csv('predictions_MULTICLASS.csv', sep='\t', encoding='utf-8')

# %%
torch.save(net, 'model_weights.pth')

test_sample = (X_test[5:15]).type(torch.FloatTensor)
prediction_model = net(test_sample)
#print(prediction_model)
output = torch.max(prediction_model,1)
print(output,y_test[5:15])
# Out:
# torch.return_types.max(
# values=tensor([14.5468,  3.3663, -0.1443,  1.5998,  8.8195,  4.8668,  7.7381,  6.9953,
#         -1.1670, -0.4630], grad_fn=<MaxBackward0>),
# indices=tensor([0, 1, 2, 1, 0, 1, 1, 1, 2, 2])) tensor([0., 1., 2., 2., 0., 1., 1., 1., 2., 2.])
